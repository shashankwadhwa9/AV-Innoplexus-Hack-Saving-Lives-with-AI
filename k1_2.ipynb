# %%
import itertools
import numpy as np
import pandas as pd
import nltk

from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from collections import Counter

# %% [markdown]
# ## Modelling

# %%
train = pd.read_pickle('train_df.pkl')
test = pd.read_pickle('test_df.pkl')

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s['Word'].values.tolist(), 
                                                           s['pos_tags'].values.tolist(), 
                                                           s['tag'].values.tolist())]
        self.grouped = self.data.groupby('Sent_ID').apply(agg_func)
        self.sentences = [s for s in self.grouped]
        
    def get_next(self):
        try: 
            s = self.grouped['Sentence: {}'.format(self.n_sent)]
            self.n_sent += 1
            return s 
        except:
            return None

# %%
getter = SentenceGetter(train)
sentences = getter.sentences

# %%
len(sentences)
# Out:
# 191282

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0, 
        'word.lower()': word.lower(), 
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features

# %%
def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %% [markdown]
# ### Split train and test sets

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %% [markdown]
# ### Train a CRF model

# %%
final_crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.003,
    c2=0.11,
    max_iterations=100,
    all_possible_transitions=True
)
final_crf.fit(X, y)

test['tag'] = ''
getter = SentenceGetter(test)
test_sentences = getter.sentences
test_X = [sent2features(s) for s in test_sentences]

preds = final_crf.predict(test_X)
preds_list = list(itertools.chain.from_iterable(preds))
submission_df = pd.DataFrame()
submission_df['id'] = test['id']
submission_df['Sent_ID'] = test['Sent_ID']
submission_df['tag'] = preds_list
submission_df.to_csv('submission_2.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0c0c471111ec> in <module>
#      13 test_X = [sent2features(s) for s in test_sentences]
#      14
# ---> 15 preds = crf.predict(test_X)
#      16 preds_list = list(itertools.chain.from_iterable(preds))
#      17 submission_df = pd.DataFrame()
#
# NameError: name 'crf' is not defined

# %%
preds = final_crf.predict(test_X)
preds_list = list(itertools.chain.from_iterable(preds))
submission_df = pd.DataFrame()
submission_df['id'] = test['id']
submission_df['Sent_ID'] = test['Sent_ID']
submission_df['tag'] = preds_list
submission_df.to_csv('submission_2.csv', index=False)

# %%
final_crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
final_crf.fit(X, y)

preds = final_crf.predict(test_X)
preds_list = list(itertools.chain.from_iterable(preds))
submission_df = pd.DataFrame()
submission_df['id'] = test['id']
submission_df['Sent_ID'] = test['Sent_ID']
submission_df['tag'] = preds_list
submission_df.to_csv('submission_3.csv', index=False)

# %%
final_crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.003,
    c2=0.11,
    max_iterations=200,
    all_possible_transitions=True
)
final_crf.fit(X, y)

preds = final_crf.predict(test_X)
preds_list = list(itertools.chain.from_iterable(preds))
submission_df = pd.DataFrame()
submission_df['id'] = test['id']
submission_df['Sent_ID'] = test['Sent_ID']
submission_df['tag'] = preds_list
submission_df.to_csv('submission_4.csv', index=False)

# %%
import eli5
eli5.show_weights(final_crf, top=10)
# Out:
# /Users/shashankwadhwa/Desktop/Work/env/ds3/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-indications</th>
#
#                 <th>I-indications</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 93.80%)" title="O &rArr; O">
#                             2.29
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.91%)" title="O &rArr; B-indications">
#                             -0.006
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 80.00%)" title="O &rArr; I-indications">
#                             -12.21
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-indications</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.86%)" title="B-indications &rArr; O">
#                             -2.806
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.09%)" title="B-indications &rArr; B-indications">
#                             -1.641
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.45%)" title="B-indications &rArr; I-indications">
#                             1.472
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-indications</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.45%)" title="I-indications &rArr; O">
#                             -1.472
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.49%)" title="I-indications &rArr; B-indications">
#                             -2.458
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.42%)" title="I-indications &rArr; I-indications">
#                             1.046
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-indications
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-indications
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.440
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():healthy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.505
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():stroma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.436
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():analysis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.337
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():pathogenesis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.939
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():apoptosis
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 86.82%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 118403 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 86.29%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 12858 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 86.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -6.282
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():ulcers
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -6.287
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():bladder
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -6.367
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():ascites
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -6.853
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
eli5.show_weights(final_crf, top=50, 
                  horizontal_layout=False, show=['targets'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=O
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.440
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():healthy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.505
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():stroma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.436
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():analysis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.337
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():pathogenesis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.939
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():apoptosis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.762
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():metabolism
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.715
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():diagnosis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.601
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():prognosis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.373
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         BOS
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.360
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():synthesis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.252
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():basis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.139
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:word.lower():scrotum
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.016
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:word.lower():streptococcus
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.917
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():hypothesis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.882
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():cases
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.860
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():empathy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.833
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():nonmelanoma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.769
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():adenomas
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.748
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         -1:word.lower():glioma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.76%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.730
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():allele
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.639
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         +1:word.lower():toxin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.600
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">

# %%
final_crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.002,
    c2=0.15,
    max_iterations=100,
    all_possible_transitions=True
)
final_crf.fit(X, y)

preds = final_crf.predict(test_X)
preds_list = list(itertools.chain.from_iterable(preds))
submission_df = pd.DataFrame()
submission_df['id'] = test['id']
submission_df['Sent_ID'] = test['Sent_ID']
submission_df['tag'] = preds_list
submission_df.to_csv('submission_5.csv', index=False)

# %%
eli5.show_weights(final_crf, top=100)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>O</th>
#
#                 <th>B-indications</th>
#
#                 <th>I-indications</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>O</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 93.22%)" title="O &rArr; O">
#                             2.301
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.78%)" title="O &rArr; B-indications">
#                             0.017
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 80.00%)" title="O &rArr; I-indications">
#                             -10.788
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B-indications</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.62%)" title="B-indications &rArr; O">
#                             -2.597
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.22%)" title="B-indications &rArr; B-indications">
#                             -1.833
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.32%)" title="B-indications &rArr; I-indications">
#                             1.353
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>I-indications</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.02%)" title="I-indications &rArr; O">
#                             -1.48
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.43%)" title="I-indications &rArr; B-indications">
#                             -2.693
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.01%)" title="I-indications &rArr; I-indications">
#                             1.079
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=O
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=B-indications
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=I-indications
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.711
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():healthy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.510
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():diagnosis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.074
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():analysis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.615
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():pathogenesis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.458
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():stroma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.347
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():apoptosis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.090
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():metabolism
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.006
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():prognosis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.882
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():synthesis
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.759
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         BOS
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.741
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word.lower():basis

# %% [markdown]
# ## Gensim Word2Vec

# %%
all_sentences = sentences + test_sentences

# %%
len(all_sentences)
# Out:
# 317122

# %%
from gensim.models.word2vec import Word2Vec

# %%
model = Word2Vec(all_sentences)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-564742712214> in <module>
# ----> 1 model = Word2Vec(all_sentences)
#
# ~/Desktop/Work/env/ds3/lib/python3.6/site-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, max_final_vocab)
#     781             callbacks=callbacks, batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window,
#     782             seed=seed, hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, compute_loss=compute_loss,
# --> 783             fast_version=FAST_VERSION)
#     784
#     785     def _do_train_epoch(self, corpus_file, thread_id, offset, cython_vocab, thread_private_mem, cur_epoch,
#
# ~/Desktop/Work/env/ds3/lib/python3.6/site-packages/gensim/models/base_any2vec.py in __init__(self, sentences, corpus_file, workers, vector_size, epochs, callbacks, batch_words, trim_rule, sg, alpha, window, seed, hs, negative, ns_exponent, cbow_mean, min_alpha, compute_loss, fast_version, **kwargs)
#     757                 raise TypeError("You can't pass a generator as the sentences argument. Try a sequence.")
#     758
# --> 759             self.build_vocab(sentences=sentences, corpus_file=corpus_file, trim_rule=trim_rule)
#     760             self.train(
#     761                 sentences=sentences, corpus_file=corpus_file, total_examples=self.corpus_count,
#
# ~/Desktop/Work/env/ds3/lib/python3.6/site-packages/gensim/models/base_any2vec.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     941             trim_rule=trim_rule, **kwargs)
#     942         report_values['memory'] = self.estimate_memory(vocab_size=report_values['num_retained_words'])
# --> 943         self.trainables.prepare_weights(self.hs, self.negative, self.wv, update=update, vocabulary=self.vocabulary)
#     944
#     945     def build_vocab_from_freq(self, word_freq, keep_raw_vocab=False, corpus_count=None, trim_rule=None, update=False):
#
# ~/Desktop/Work/env/ds3/lib/python3.6/site-packages/gensim/models/word2vec.py in prepare_weights(self, hs, negative, wv, update, vocabulary)
#    1840         # set initial input/projection and hidden weights
#    1841         if not update:
# -> 1842             self.reset_weights(hs, negative, wv)
#    1843         else:
#    1844             self.update_weights(hs, negative, wv)
#
# ~/Desktop/Work/env/ds3/lib/python3.6/site-packages/gensim/models/word2vec.py in reset_weights(self, hs, negative, wv)
#    1857         for i in range(len(wv.vocab)):
#    1858             # construct deterministic seed from word AND seed argument
# -> 1859             wv.vectors[i] = self.seeded_vector(wv.index2word[i] + str(self.seed), wv.vector_size)
#    1860         if hs:
#    1861             self.syn1 = zeros((len(wv.vocab), self.layer1_size), dtype=REAL)
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %%
all_sentences[0]
# Out:
# [('Obesity', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Low-', 'NNP', 'O'),
#  ('and', 'CC', 'O'),
#  ('Middle-Income', 'JJ', 'O'),
#  ('Countries', 'NNS', 'O'),
#  (':', ':', 'O'),
#  ('Burden', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('Drivers', 'NNP', 'O'),
#  (',', ',', 'O'),
#  ('and', 'CC', 'O'),
#  ('Emerging', 'NNP', 'O'),
#  ('Challenges', 'NNP', 'O'),
#  ('.', '.', 'O')]

# %%
from nltk.corpus import stopwords

# %%
stop = set(stopwords.words('english'))

# %%
import string

# %%
all_sentences_str = []

for sent in all_sentences:
    sent_list = []
    for tup in sent:
        w = tup[0].lower()
        if w not in stop and w not in string.punctuation:
            sent_list.append(w)
        
    all_sentences_str.append(sent_list)

# %%
len(all_sentences_str)
# Out:
# 317122

# %%
len(all_sentences)
# Out:
# 317122

# %%
all_sentences_str[0]
# Out:
# ['obesity',
#  'low-',
#  'middle-income',
#  'countries',
#  'burden',
#  'drivers',
#  'emerging',
#  'challenges']

# %%
model = Word2Vec(all_sentences_str)

# %%
model.wv.vocab['obesity']

# %%
X = model[model.wv.vocab]
from sklearn import cluster
from sklearn import metrics
kmeans = cluster.KMeans(n_clusters=4)
kmeans.fit(X)
 
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
 
print ("Cluster id labels for inputted data")
print (labels)
print ("Centroids data")
print (centroids)
 
print ("Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):")
print (kmeans.score(X))
 
silhouette_score = metrics.silhouette_score(X, labels, metric='euclidean')
 
print ("Silhouette_score: ")
print (silhouette_score)
# Out:
# /Users/shashankwadhwa/Desktop/Work/env/ds3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# Cluster id labels for inputted data
# [1 0 0 ... 0 0 0]
# Centroids data
# [[-6.09064326e-02  6.93934225e-03  8.18303227e-02  9.59293246e-02
#   -4.17350903e-02  3.37703433e-03 -1.11806765e-01 -8.21769703e-03
#   -6.58003464e-02  1.34621575e-01 -6.99720457e-02 -5.32562360e-02
#    9.91727263e-02  6.21661097e-02  3.88370678e-02  7.88711980e-02
#    2.39928663e-02  2.36820392e-02 -1.31008010e-02  5.02174161e-02
#   -2.84048636e-02  1.78205937e-01  5.11017703e-02  7.26875737e-02
#   -1.58423968e-02 -8.88578780e-03  3.50871533e-02 -7.03259325e-03
#    1.18742481e-01 -1.08677400e-02  7.39399791e-02 -2.05799565e-02
#   -5.52190468e-05 -5.81533276e-02 -9.96536948e-03 -4.37295362e-02
#   -2.34889369e-02  3.42863724e-02  8.18537101e-02  6.52742162e-02
#    2.73405574e-02 -8.83256719e-02 -2.34338250e-02  5.30511364e-02
#   -3.05720270e-02  5.62617891e-02 -7.55729526e-02  2.54525319e-02
#    1.21359222e-01 -2.31589973e-02 -3.31633687e-02 -3.26177701e-02
#    6.90273643e-02 -1.10205337e-01 -1.23245403e-01  1.59133703e-01
#    6.55853897e-02 -9.37866494e-02 -4.32290919e-02 -1.15335137e-01
#    6.55838922e-02 -3.10561489e-02  3.11948694e-02  2.12102413e-01
#    2.84702778e-02  1.53360203e-01  4.89757806e-02  8.53827596e-03
#   -5.42554855e-02  1.11896060e-02 -5.62259518e-02 -9.07289423e-03
#   -2.76988233e-03  6.92813620e-02  4.91176359e-02  3.03565376e-02
#   -4.49626036e-02  9.92692038e-02  4.12338078e-02  3.18436921e-02
#    1.53934211e-03 -4.25048396e-02 -1.92940701e-02 -6.62500225e-03
#    3.78417298e-02  1.74926482e-02 -7.02201501e-02 -5.91418929e-02
#    7.84979835e-02  3.04110385e-02  1.72819421e-01  1.88743576e-01
#   -7.20875524e-03  3.42574380e-02  2.16379203e-02 -9.20683667e-02
#    2.25255452e-02 -7.86927864e-02 -5.43063991e-02 -1.22627228e-01]
#  [ 9.06052440e-02  3.37459072e-02  1.50629029e-01  2.57143646e-01
#   -2.58472323e-01  2.27184728e-01 -6.22770935e-03  6.12027235e-02
#   -3.22937578e-01  4.82768357e-01 -1.62170410e-01 -2.03651696e-01
#    3.14924940e-02  6.56464696e-03  6.52251661e-01  8.64935890e-02
#    3.89948487e-04  1.86727464e-01 -1.06366977e-01 -1.88529074e-01
#    4.11584586e-01  2.14796305e-01  4.20603573e-01  7.17242479e-01
#   -1.13109164e-01  3.55116695e-01 -1.74522802e-01 -3.48772615e-01
#    1.92160726e-01 -1.50998786e-01 -9.45991352e-02  8.93697664e-02
#   -2.24944398e-01 -3.04538786e-01  8.61270055e-02  4.27536815e-01
#   -4.07117009e-01  2.75169373e-01  1.05035946e-01  5.24302006e-01
#    5.05476832e-01 -4.61567670e-01 -6.64039135e-01  4.41656321e-01
#   -2.85240173e-01 -6.71050176e-02 -8.30167532e-01  2.23168954e-01
#    2.94739902e-01 -1.08410865e-01 -8.41583759e-02 -2.22464919e-01
#    4.59222108e-01  1.53745383e-01  1.51517406e-01  7.53160894e-01
#    7.21688345e-02 -3.25617716e-02  2.18501478e-01 -3.98136377e-01
#    3.56969953e-01 -1.38430849e-01 -1.77953206e-02  3.58759165e-01
#    6.12406552e-01  5.82722902e-01  2.59029329e-01 -6.24082983e-02
#   -2.54318327e-01 -2.53526509e-01  4.05764580e-01  1.13592215e-01
#   -2.66337633e-01 -1.01690799e-01  7.91301429e-02 -4.86636430e-01
#    1.08391859e-01  4.51128393e-01  3.53976429e-01  4.28606011e-02
#    2.78272778e-01 -7.66434193e-01 -1.11092955e-01 -1.51590437e-01
#    2.39559650e-01  1.92172498e-01 -2.71436393e-01  2.06347585e-01
#    3.68296593e-01 -7.44536668e-02  6.76258564e-01  3.22154582e-01
#   -1.28191888e-01  6.00722656e-02 -5.47264874e-01 -5.14535010e-01
#    2.37745136e-01 -3.96736979e-01  3.35720837e-01 -3.89224052e-01]
#  [-4.98176515e-01  1.31564289e-01  5.66344500e-01 -1.63607866e-01
#    1.67815745e-01 -1.69214174e-01 -3.82330239e-01  5.24720736e-02
#   -4.52912211e-01  4.82934505e-01 -2.79051036e-01 -2.28230268e-01
#    2.14889914e-01  5.80347896e-01 -4.06420141e-01  4.45398629e-01
#    1.81290239e-01 -1.27316117e-01  3.37194234e-01  2.74749488e-01
#   -4.01274592e-01  7.71190763e-01 -4.41190660e-01 -4.23099637e-01
#    4.25548926e-02 -1.18466645e-01  3.60602826e-01 -1.70533806e-01
#    8.52569461e-01  3.33556384e-01  6.46952540e-02 -3.91374454e-02
#    2.49627665e-01 -4.41500962e-01 -2.14500055e-01 -1.84814140e-01
#    9.75185260e-02  1.54457033e-01  5.29475622e-02 -6.70254081e-02
#    1.14705741e-01  6.57883957e-02 -3.10132027e-01 -1.50087290e-02
#   -2.24534616e-01  1.28668994e-01 -8.14203173e-03  2.97245592e-01
#    2.39896387e-01 -3.89570832e-01 -1.73144918e-02 -5.17283753e-03
#    3.29791814e-01 -2.75947213e-01 -6.61222339e-01 -1.35215223e-02
#    1.35368824e-01 -5.63812196e-01 -4.95505661e-01 -6.20753646e-01
#   -2.01173380e-01 -2.60278285e-01  1.95364788e-01  6.22643709e-01
#   -1.36543185e-01  9.73866060e-02 -7.11409748e-03  8.59059319e-02
#   -8.54551122e-02  1.17101148e-01 -1.63339674e-01 -1.07232623e-01
#   -2.11655572e-02  1.92124039e-01  2.39947170e-01  3.74392480e-01
#    2.62915269e-02  3.44487220e-01  1.90779611e-01  1.21671148e-01
#   -4.26716536e-01 -2.92038918e-03 -6.46807775e-02 -3.26400131e-01
#   -1.65656447e-01 -2.51805782e-01 -8.69790986e-02  9.85047668e-02
#    1.11459114e-01  2.43086666e-01  6.74533129e-01  5.07356644e-01
#   -1.38618305e-01  2.71810889e-01  1.60173029e-01 -3.81051958e-01
#   -4.16008294e-01 -3.28117698e-01 -5.12100339e-01 -3.79281223e-01]
#  [ 2.23365590e-01 -3.41059804e-01 -3.81005555e-03  4.23856705e-01
#   -3.77198786e-01 -1.26723796e-01 -2.03681588e-01 -1.94466906e-03
#    1.48404121e-01  7.08350986e-02  1.19301744e-01  3.87264788e-02
#    1.58235356e-02 -9.16408300e-02 -4.21593606e-01  8.19088370e-02
#    1.80669591e-01 -4.04064730e-02 -3.36706936e-01  2.38959461e-01
#    8.07184279e-02  6.03359222e-01  4.86715317e-01  1.46524623e-01
#   -2.28163347e-01 -2.17990085e-01 -2.12695792e-01  6.09629333e-01
#   -1.58167526e-01  1.49870347e-02  1.53440505e-01  5.44170439e-02
#   -2.86090583e-01  9.89784300e-02  2.74843425e-01 -8.44889462e-01
#   -2.85573691e-01  1.08759075e-01  5.58647454e-01 -7.11392760e-02
#   -3.11186731e-01 -4.74842459e-01  3.04743737e-01 -1.51117951e-01
#    3.21757406e-01  1.83956757e-01 -5.10245144e-01 -4.02484357e-01
#    6.62253082e-01  3.44114780e-01 -1.63195878e-01 -4.27965298e-02
#   -6.75974071e-01 -1.12304822e-01 -4.63797867e-01  6.26775265e-01
#    2.76565909e-01 -8.58526081e-02 -5.09145856e-01 -5.52208275e-02
#    8.39755476e-01  2.66455859e-03 -1.32233240e-02  6.00699782e-01
#    5.45807838e-01  5.46332538e-01  4.06361818e-01  3.40054035e-02
#   -2.30106115e-01  8.53848830e-03 -3.76228094e-01 -5.01742363e-02
#    1.87790453e-01 -1.91084176e-01  6.86295748e-01 -1.62861466e-01
#   -7.89188802e-01 -9.43712145e-02 -2.57926404e-01  3.72335792e-01
#   -7.95559585e-02 -1.82526037e-01 -2.07166210e-01  4.09529328e-01
#    8.00995082e-02 -1.08976275e-01 -2.89155960e-01 -4.94153291e-01
#    2.70619333e-01 -3.38926315e-01  1.07854627e-01  7.94263840e-01
#    2.78989255e-01 -3.39369066e-02  1.61172748e-01 -3.01438868e-01
#    5.57016909e-01  1.66018903e-01  2.20884621e-01 -1.25372469e-01]]
# Score (Opposite of the value of X on the K-means objective which is Sum of distances of samples to their closest cluster center):
# -293020.4
# Silhouette_score:
# 0.64429504

# %%
len(labels)
# Out:
# 50227

# %%
len(X)
# Out:
# 50227

# %%
word_clusters = {}
ctr = 0
for word, vocab_obj in model.wv.vocab.items():
    word_clusters[word] = kmeans.labels_[ctr]
    ctr += 1

# %%
def word2features2(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    cluster = str(word_clusters.get(word.lower(), '4'))
    
    features = {
        'bias': 1.0, 
        'word.lower()': word.lower(), 
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
        'cluster': cluster
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features

# %%
def sent2features2(sent):
    return [word2features2(sent, i) for i in range(len(sent))]

# %%
X = [sent2features2(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# %%
final_crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.003,
    c2=0.11,
    max_iterations=100,
    all_possible_transitions=True
)
final_crf.fit(X, y)

test['tag'] = ''
getter = SentenceGetter(test)
test_sentences = getter.sentences
test_X = [sent2features2(s) for s in test_sentences]

preds = final_crf.predict(test_X)
preds_list = list(itertools.chain.from_iterable(preds))
submission_df = pd.DataFrame()
submission_df['id'] = test['id']
submission_df['Sent_ID'] = test['Sent_ID']
submission_df['tag'] = preds_list
submission_df.to_csv('submission_6.csv', index=False)

# %%
c = {}

for word, cluster in word_clusters.items():
    try:
        c[cluster].append(word)
    except:
        c[cluster]= [word]

# %%
c[2]
# Out:
# ['excess',
#  'region',
#  'differential',
#  'occurs',
#  'changes',
#  'activity',
#  'hypothesized',
#  'leading',
#  'stress',
#  'dysregulation',
#  'mechanisms',
#  'reverse',
#  'also',
#  'contrast',
#  'reactivity',
#  'reactive',
#  'thermal',
#  'expressed',
#  'conductance',
#  'function',
#  'simultaneous',
#  'showed',
#  'moreover',
#  'signal',
#  'action',
#  'frog',
#  'putative',
#  'chloride',
#  'channel',
#  'single',
#  'c-terminal',
#  'transmembrane',
#  'proteins',
#  'plasma',
#  'membrane',
#  'cl',
#  'channels',
#  'could',
#  'activated',
#  'calcium',
#  'human',
#  'protein',
#  'precursor',
#  'n-terminal',
#  'sequence',
#  'cleavage',
#  'near',
#  'amino',
#  'acid',
#  'geometry',
#  'suggested',
#  'derived',
#  'architecture',
#  'hydrophobic',
#  'antibody',
#  'investigated',
#  'synthesis',
#  'localization',
#  'maturation',
#  'cell',
#  'surface',
#  'h',
#  'revealed',
#  'endoplasmic',
#  'reticulum',
#  'products',
#  'detected',
#  'product',
#  'medium',
#  'whereas',
#  'retained',
#  'demonstrated',
#  'preferential',
#  'release',
#  'transfer',
#  'secreted',
#  'form',
#  'green',
#  'fluorescent',
#  'sufficient',
#  'target',
#  'together',
#  'indicate',
#  'extracellular',
#  'cytoplasmic',
#  'tail',
#  'self-assembled',
#  'vivo',
#  'lipid',
#  'derivative',
#  'synthesized',
#  'confirmed',
#  'monolayer',
#  'formed',
#  'mixture',
#  'injected',
#  'water',
#  'spherical',
#  'vesicles',
#  'electron',
#  'nm',
#  'mv',
#  'stable',
#  'weakly',
#  'acidic',
#  'neutral',
#  'mouse',
#  'degraded',
#  'cytotoxicity',
#  'lines',
#  'probably',
#  'substitution',
#  'mainly',
#  'mononuclear',
#  'macrophage',
#  'spleen',
#  'mice',
#  'effect',
#  'shown',
#  'anticancer',
#  'indicates',
#  'leptin',
#  'resistance',
#  'tissue',
#  'inhibitor',
#  'deficient',
#  'complex',
#  'signals',
#  'hypothalamus',
#  'physiological',
#  'alterations',
#  'plasticity',
#  'matrix',
#  'metalloproteinase',
#  'mmp',
#  '-mediated',
#  'proteolysis',
#  'inhibition',
#  'contributes',
#  'role',
#  'hypothalamic',
#  'homeostasis',
#  'regulation',
#  'knockout',
#  'ko',
#  'fed',
#  'wild-type',
#  'wt',
#  'neuropeptide',
#  'expression',
#  'resistant',
#  'reduced',
#  'response',
#  'activator',
#  'transcription',
#  'activation',
#  'addition',
#  'nucleus',
#  'suggest',
#  'forming',
#  'produce',
#  'present',
#  'dominant',
#  'strong',
#  'functions',
#  'effects',
#  'found',
#  'partially',
#  'dependent',
#  'fluorescence',
#  'high-performance',
#  'liquid',
#  'chromatography',
#  'b1',
#  'phase',
#  'ph',
#  'column',
#  'temperature',
#  'extraction',
#  'corn',
#  'negatively',
#  'positively',
#  'resulted',
#  'agents',
#  'damage',
#  'prostaglandin',
#  'somatostatin',
#  'highly',
#  'epidermal',
#  'growth',
#  'factor',
#  'enhances',
#  'triggered',
#  'mitochondrial',
#  'shows',
#  'contribute',
#  'mutation',
#  'genes',
#  'implicated',
#  'mitochondria',
#  'characterization',
#  'induction',
#  'accumulates',
#  'deletion',
#  'gene',
#  'induce',
#  'specifically',
#  'neurons',
#  'generated',
#  'transgenic',
#  'ornithine',
#  'tyrosine',
#  'hydroxylase',
#  'promoter',
#  'characterized',
#  'induced',
#  'dopaminergic',
#  'responsiveness',
#  'demonstrate',
#  'accumulation',
#  'phenotype',
#  'overexpressed',
#  'show',
#  'phenotypes',
#  'production',
#  'enzyme',
#  'fungus',
#  'sp',
#  'enhancing',
#  'enzymes',
#  'produced',
#  'isolated',
#  'optimum',
#  'straw',
#  'ii',
#  'iii',
#  'iv',
#  'decomposition',
#  'concentrations',
#  'incubation',
#  'activities',
#  'efficiency',
#  'degradation',
#  'b',
#  'red',
#  'rb',
#  'oxygen',
#  'virus',
#  'metabolic',
#  'determined',
#  'indirectly',
#  '-1',
#  'aerobic',
#  'capacity',
#  'attenuation',
#  'active',
#  'combination',
#  'plate',
#  'like',
#  'concentration',
#  'combinations',
#  'modifications',
#  'phases',
#  'additives',
#  'organic',
#  'chiral',
#  'gold',
#  'nanoparticles',
#  'coated',
#  '2d',
#  'directly',
#  'coupling',
#  'quantum',
#  'dots',
#  'detection',
#  'e',
#  'da',
#  'este',
#  'sobre',
#  'el',
#  'de',
#  'com',
#  'la',
#  'por',
#  'en',
#  'se',
#  'entre',
#  'las',
#  'con',
#  'una',
#  'que',
#  'como',
#  'para',
#  'defective',
#  'vector',
#  'brain',
#  'exogenous',
#  'molecular',
#  'affect',
#  'modulate',
#  'neurotransmitter',
#  'altered',
#  'neuronal',
#  'regulate',
#  'pathways',
#  'specific',
#  'recombinant',
#  'structure',
#  'determination',
#  'spectrometry',
#  'molecules',
#  'sequences',
#  'biologically',
#  'reveals',
#  'suppression',
#  'proliferation',
#  'apoptosis',
#  'tumorigenesis',
#  'alter',
#  'chromatin',
#  'senescence',
#  'transformation',
#  'member',
#  'encodes',
#  'plant',
#  'interacts',
#  'p53',
#  'suppressor',
#  'cofactor',
#  'cells',
#  'endogenous',
#  'levels',
#  'inhibit',
#  'fibroblasts',
#  'induces',
#  'bax',
#  'increases',
#  'dna',
#  'suppresses',
#  'formation',
#  'b-cell',
#  'furthermore',
#  'reveal',
#  'manner',
#  'prolactin',
#  'incubated',
#  'histamine',
#  'gamma-aminobutyric',
#  'gaba',
#  'acetylcholine',
#  'ach',
#  'antagonists',
#  'stimulated',
#  'inhibited',
#  'responses',
#  'blocked',
#  'dopamine',
#  'antagonist',
#  'adrenergic',
#  'alpha',
#  'beta',
#  'cholinergic',
#  'prevented',
#  'blocker',
#  'atropine',
#  'neither',
#  'stimulation',
#  'noradrenaline',
#  'releasing',
#  'chicken',
#  'stimulate',
#  'secretion',
#  'forms',
#  'vitro',
#  'indicated',
#  'chromosomal',
#  'exposure',
#  'magnitude',
#  'substances',
#  'absence',
#  'pure',
#  'exposed',
#  'chromosome',
#  'detectable',
#  'consequence',
#  'drosophila',
#  'mutagenic',
#  'microg',
#  'consistent',
#  'weak',
#  'circular',
#  'dichroism',
#  'experiments',
#  'mechanism',
#  'direct',
#  'interaction',
#  'resulting',
#  'conformational',
#  'helix',
#  'stability',
#  'chromosomes',
#  'strain',
#  'species',
#  'susceptibility',
#  'added',
#  'showing',
#  'profiles',
#  'cadmium',
#  'cell-mediated',
#  'bearing',
#  'ppm',
#  'assay',
#  'enhanced',
#  'enhancement',
#  'inversely',
#  'involved',
#  'blocking',
#  'interleukin-1',
#  'il-1',
#  'conditioned',
#  'cultures',
#  'driven',
#  'abolished',
#  'radioimmunoassay',
#  'identical',
#  'macrophages',
#  'oxidation',
#  'triggers',
#  'ag',
#  'nps',
#  'gram-positive',
#  'gram-negative',
#  'bacteria',
#  'strains',
#  'candida',
#  'prepared',
#  'precipitation',
#  'silver',
#  'nitrate',
#  'potassium',
#  'bromide',
#  'presence',
#  'stabilizing',
#  'polymers',
#  'peg',
#  'mode',
#  'polymer',
#  'ions',
#  'small',
#  'interact',
#  'strongly',
#  'transformed',
#  'microbial',
#  'yeast',
#  'antibacterial',
#  'radical',
#  'fragments',
#  'cluster',
#  'phenotypic',
#  'domain',
#  'light',
#  'trace',
#  'element',
#  'composition',
#  '/i',
#  'chamber',
#  'hence',
#  'whole',
#  'outer',
#  'inner',
#  'layer',
#  'decreases',
#  'absent',
#  'presumably',
#  'constant',
#  'insoluble',
#  'fractionation',
#  'serotonergic',
#  'known',
#  'marker',
#  'serotonin',
#  'transporter',
#  'binding',
#  'terminals',
#  'nuclei',
#  'resting',
#  'regions',
#  'generation',
#  'distribution',
#  'thus',
#  'previously',
#  'hg',
#  'glutamatergic',
#  'novel',
#  'derivatives',
#  '5-ht',
#  'receptor',
#  'agonists',
#  'glutamate',
#  'allosteric',
#  'compound',
#  'targeting',
#  'al',
#  'polymorphonuclear',
#  'leukocytes',
#  'modified',
#  'mixed',
#  'saturation',
#  'hydrogen',
#  'catalyzed',
#  'site',
#  'catalysts',
#  'producing',
#  'h2',
#  'upon',
#  'protons',
#  'co',
#  'ethylene',
#  'f',
#  '2+',
#  '1h',
#  'ligand',
#  'amine',
#  'fe',
#  'core',
#  'catalytic',
#  'slow',
#  'catalyst',
#  'similarly',
#  'agent',
#  'inactive',
#  'ligands',
#  'interacting',
#  'glucose',
#  'insulin',
#  'triglyceride',
#  'capillary',
#  'rabbit',
#  'cortical',
#  'indicating',
#  'gradient',
#  'potentials',
#  'rapid',
#  'closely',
#  'targets',
#  'component',
#  'linear',
#  'pattern',
#  'attenuated',
#  'modulates',
#  'differentiated',
#  'modification',
#  'undergoes',
#  'conversion',
#  'reactions',
#  'lithium',
#  'ion',
#  'charge',
#  'voltage',
#  'v',
#  'reaction',
#  'x-ray',
#  'diffraction',
#  'absorption',
#  'spectroscopy',
#  'irreversible',
#  'step',
#  'redox',
#  'pair',
#  'reversible',
#  'density',
#  'dft',
#  'block',
#  'titanium',
#  'elastic',
#  'b.',
#  'apparatus',
#  'endocytosis',
#  'kinases',
#  'signaling',
#  'ubiquitin',
#  'ligase',
#  'receptors',
#  'chains',
#  'monomers',
#  'isolation',
#  'mediates',
#  'fused',
#  'egfr',
#  'mutants',
#  'kinase',
#  'conjugation',
#  'distinct',
#  'scattering',
#  'sites',
#  'generates',
#  'possibly',
#  'appears',
#  'linker',
#  'metal',
#  'cation',
#  'exchange',
#  'rapidly',
#  'ache',
#  'deficiency',
#  'forebrain',
#  'neurotransmission',
#  'catabolism',
#  'acetylcholinesterase',
#  'toxicity',
#  'chemical',
#  'inhibitors',
#  '3-',
#  'variations',
#  'localized',
#  'mutagenesis',
#  'amplified',
#  'polymerase',
#  'chain',
#  'pcr',
#  'plasmid',
#  'containing',
#  'homology',
#  'recombination',
#  'efficient',
#  'escherichia',
#  'coli',
#  'facilitates',
#  'native',
#  'regulating',
#  'biomass',
#  'suppressed',
#  'dramatically',
#  'shift',
#  'mediated',
#  'via',
#  'transforming',
#  'amount',
#  'mediating',
#  'melatonin',
#  'biochemical',
#  'sperm',
#  'peroxidation',
#  'motility',
#  'malondialdehyde',
#  'glutathione',
#  'peroxidase',
#  'oxidative',
#  'markedly',
#  'curcumin',
#  'modulating',
#  'c-myc',
#  'pathway',
#  'possess',
#  'properties',
#  'mtt',
#  'assays',
#  'cytometry',
#  'phosphorylation',
#  'pten',
#  'akt',
#  'bcl-2',
#  'caspase-3',
#  'parp',
#  'time-dependent',
#  'upregulation',
#  'downregulation',
#  'caspase',
#  'suggesting',
#  'play',
#  'roles',
#  'edge',
#  'optical',
#  'segments',
#  'glucagon',
#  'viral',
#  'toxin',
#  'adhesive',
#  'expressions',
#  'mutant',
#  'altering',
#  'elucidated',
#  'c',
#  'c.',
#  'culture',
#  'variants',
#  'proliferative',
#  'inhibits',
#  'characteristic',
#  'rich',
#  'cysteine',
#  'rat',
#  'glycoprotein',
#  'endothelial',
#  'mrna',
#  'platelet-derived',
#  'fibroblast',
#  'synthetic',
#  'peptide',
#  'situ',
#  'hybridization',
#  'epithelial',
#  'cellular',
#  'antibodies',
#  'antigens',
#  'mobility',
#  'cathepsin',
#  'g',
#  'corresponding',
#  'nervous',
#  'line',
#  'structures',
#  'transition',
#  'angiotensin',
#  'cultured',
#  'ang',
#  'tnf',
#  'basal',
#  'cytokine',
#  'biphasic',
#  'tnf-α',
#  'demonstrating',
#  'antagonized',
#  'neutralizing',
#  'mediator',
#  'a1',
#  'a2',
#  'adenosine',
#  'components',
#  'docking',
#  'reacted',
#  'carbonyl',
#  'hydroxyl',
#  'double',
#  'bond',
#  'compounds',
#  'bind',
#  'antiviral',
#  'phosphate',
#  'ec',
#  'exhibited',
#  'potent',
#  'slightly',
#  'able',
#  'synthesize',
#  'magnetic',
#  'mixing',
#  'glass',
#  'substrate',
#  'assembled',
#  'fabrication',
#  'tolerance',
#  'microm',
#  'pump',
#  'dual',
#  'contains',
#  'mutations',
#  'bulk',
#  'autoantibodies',
#  'dark',
#  'remarkably',
#  'selective',
#  'hair',
#  'steroid',
#  'essential',
#  'purification',
#  'transcriptase',
#  'portion',
#  'hiv-1',
#  'conserved',
#  'extract',
#  'kd',
#  'rnase',
#  'migration',
#  'normally',
#  'restricted',
#  'tissues',
#  'solid',
#  'neuroblastoma',
#  'preparations',
#  'metabolism',
#  'carbohydrate',
#  'heterogeneous',
#  'dissociation',
#  'differentiation',
#  'embryonic',
#  'raw',
#  'ash',
#  'accumulated',
#  'depleted',
#  'bioactive',
#  'chorionic',
#  'isoforms',
#  'hcg',
#  'isoform',
#  'separated',
#  'quantified',
#  'circulating',
#  'potency',
#  'analogues',
#  'elution',
#  'trophoblast',
#  'molecule',
#  'insects',
#  'encoded',
#  'inhibitory',
#  'diminished',
#  'd.',
#  'resonance',
#  'experimentally',
#  'intact',
#  'cartilage',
#  'proton',
#  'parallel',
#  'matter',
#  'coding',
#  'insect',
#  'testosterone',
#  'fsh',
#  'lh',
#  'progesterone',
#  'immunized',
#  'conjugate',
#  'cycle',
#  '0.1',
#  'leads',
#  'hypothesis',
#  'plays',
#  'presynaptic',
#  'synapse',
#  'crystal',
#  'domains',
#  'synaptic',
#  'mediators',
#  'vectors',
#  'serotype',
#  'transduction',
#  'vegf',
#  'transgene',
#  'organisms',
#  'washed',
#  'regulators',
#  'display',
#  'aberrant',
#  'scaffolds',
#  'structurally',
#  'transporters',
#  'functionally',
#  'lectin',
#  'effectors',
#  'resin',
#  'salts',
#  'glycol',
#  'effectively',
#  'content',
#  'acetate',
#  'diffusion',
#  'buffer',
#  'attributed',
#  'solubility',
#  'loading',
#  'polymerization',
#  'r',
#  'lethal',
#  'coupled',
#  'employing',
#  'profiling',
#  'lacking',
#  'cytotoxic',
#  'lymphocyte',
#  'predominantly',
#  'lymphocytes',
#  'leukocyte',
#  'aggregation',
#  'interleukin',
#  'truncated',
#  '250',
#  'il-2',
#  'regulatory',
#  'treg',
#  'immune',
#  't-cell',
#  'effector',
#  'activating',
#  'moisture',
#  'emissions',
#  'islets',
#  'olfactory',
#  'mediate',
#  'exclusively',
#  'stimulatory',
#  'ganglia',
#  'cdna',
#  'nucleotide',
#  'retina',
#  'blot',
#  'immunohistochemistry',
#  'photoreceptor',
#  'located',
#  'frequencies',
#  'conjugated',
#  'film',
#  'hybrid',
#  'composed',
#  'copolymer',
#  'films',
#  'incorporation',
#  'spectra',
#  'anisotropy',
#  'exhibit',
#  'transport',
#  'probe',
#  'ciliary',
#  'epithelium',
#  'bodies',
#  'solutions',
#  'cl-',
#  'solution',
#  'intracellular',
#  'na+',
#  'k+',
#  'na',
#  'k',
#  'contents',
#  'ouabain',
#  'aqueous',
#  'inhibiting',
#  'pro-inflammatory',
#  'pigment',
#  'aβ',
#  'cytokines',
#  'nf-κb',
#  'regulator',
#  'nuclear',
#  'translocation',
#  'silencing',
#  'activate',
#  'anti-inflammatory',
#  'lc',
#  'dorsal',
#  'microscope',
#  'namely',
#  'th1',
#  'th2',
#  'apparent',
#  'acetic',
#  'batch',
#  'pi',
#  'converted',
#  'sequenced',
#  'genomes',
#  'constitutive',
#  'inactivation',
#  'scavenging',
#  'viability',
#  'accumulate',
#  'toxic',
#  'atoms',
#  'microscopy',
#  'phenolic',
#  'turn',
#  'fractions',
#  'linked',
#  'peaks',
#  'plants',
#  'dependence',
#  'sub',
#  '/sub',
#  'sup',
#  '/sup',
#  'nitrogen',
#  'interestingly',
#  'electrospray',
#  'ionization',
#  'methanol',
#  'l',
#  'ethanol',
#  'intermolecular',
#  'interactions',
#  'temperatures',
#  'relaxation',
#  'dc',
#  's.',
#  'paramagnetic',
#  'ac',
#  'free',
#  'invasion',
#  'stromal',
#  'remodeling',
#  'microenvironment',
#  'ex',
#  'sodium',
#  'regulates',
#  'genome',
#  'cloned',
#  'luciferase',
#  'reporter',
#  'h.',
#  'clone',
#  'digestion',
#  ...]
